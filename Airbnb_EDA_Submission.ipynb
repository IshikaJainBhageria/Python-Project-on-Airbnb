# %% [markdown]
# # **Project Name**    -

# %% [markdown]
#  **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# **Key Challenges to Address:**
#
# Understanding Market Dynamics and Trends: Airbnb operates in a highly dynamic environment where customer preferences, market demands, and regional trends can significantly impact the platform's performance. Analyzing the dataset can reveal insights into how listings are distributed geographically, which property types and amenities are most popular, and how pricing strategies vary across locations and seasons. Identifying these patterns can help Airbnb optimize listings and offer tailored recommendations to both hosts and guests.
#
# Enhancing Customer and Host Experience: A key differentiator for Airbnb is its focus on personalized experiences. By analyzing customer reviews, ratings, and booking trends, the company can identify what drives guest satisfaction and host performance. Insights into common pain points and preferred features can guide improvements in platform functionality and customer support initiatives.
#
# Pricing and Revenue Optimization: Price is a critical factor in a guest's decision-making process. Airbnb can use this dataset to explore how pricing impacts occupancy rates and host revenue. Advanced analytics can help in designing dynamic pricing models that balance affordability for guests with profitability for hosts.
#
# Security and Trust Enhancement: With millions of transactions happening on the platform, ensuring security and trust is essential. Data analysis can uncover fraudulent patterns, suspicious activities, or anomalies in user behavior. This can help Airbnb refine its trust and safety measures, thereby maintaining the integrity of its platform.
#
# Marketing and Strategic Expansion: Analyzing the dataset can highlight untapped markets, emerging trends, and customer segments. Airbnb can use these insights to guide marketing campaigns, expand into new regions, or introduce innovative services such as curated travel experiences or loyalty programs.
#
# Sustainability and Long-Term Growth: By examining host and guest behavior, listing performance, and platform engagement, Airbnb can make data-driven decisions to support long-term growth. This includes identifying high-performing hosts, evaluating the success of new features, and planning future investments.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective is to leverage data-driven insights to optimize Airbnb's platform performance, enhance user experiences, and drive sustainable growth.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# !pip install pymysql
import pymysql
from sqlalchemy import create_engine
from sqlalchemy.pool import NullPool

import warnings
warnings.filterwarnings('ignore')
# Out:
# <ipython-input-1-e56664d87ad8>:4: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   from numpy import math
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data = pd.read_csv("/content/Airbnb NYC 2019.csv")
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicates = len(data[data.duplicated()])
print(duplicates)
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(data.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The above dataset is of airbnb. It has 48895 rows and 16 columns with 0 duplicate values and 16 missing values in name column, 21 in host name, 10052 in last review and review per month each. The business objective is to leverage data-driven insights to optimize Airbnb's platform performance, enhance user experiences, and drive sustainable growth.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
data.describe(include = "all")
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Dataset Description
#
# ![Capture.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in data.columns.tolist():
  print("No. of unique values in ",i,"is",data[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  name is 47905 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  host_name is 11452 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  last_review is 1764 .
# No. of unique values in  reviews_per_month is 937 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Dropping the duplicates
data.drop(duplicates, inplace = True) #No duplicates

# %%
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Filling the missing values
data['name'].fillna("['Unknown']", inplace = True)

# %%
data['name'].isnull().sum()
# Out:
# 0

# %%
data['host_name'].fillna("['Unknown']", inplace = True)

# %%
data['host_name'].isnull().sum()
# Out:
# 0

# %%
data['last_review'].fillna("['Unknown']", inplace = True)

# %%
data['last_review'].isnull().sum()
# Out:
# 0

# %%
import seaborn as sns
sns.histplot(x=data['reviews_per_month'])
# Out:
# <Axes: xlabel='reviews_per_month', ylabel='Count'>

# %%
data['reviews_per_month'].skew()
# Out:
# 3.1301612421391707

# %%
data['reviews_per_month'].fillna(data['reviews_per_month'].median() ,inplace=True)

# %%
data['reviews_per_month'].isnull().sum()
# Out:
# 0

# %%
data
# Out:
#              id                                               name   host_id  \
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East      7322
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I did all the basic checks and then I identified the missing and duplicate values. There were zero duplicate values, so, there was nothing to drop. Then I filled missing values with the most appropriate options. Now, this data is completely cleaned and ready to analyse more.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# x-axis = neighbourhood_group | y-axis = price
# Bar chart

plt.figure(figsize=(10,3))
sns.barplot(x=data['neighbourhood_group'],y=data['price'])
plt.title('neighbourhood_group v/s price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this specific chart because I wanted to show two paratemeters, one is numerical and another one is categorical. To analyse the relationship b/w two such parameters, bar plot is best.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Prices of airbnb in Manhattan are the most expensive making it the most premium area.
# 2. Prices in Bronx are the lowest, making it the most affordable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights can help the organization to identify at which neighbourhood area, what prices avail and how costly or nominal it is for the customer. Yes, it will create a positive business impact by targeting customers as per the neighbourhood prices.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Pie chart
# Portion of each neighbourhood group

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each neighbourhood group
neighbourhood_counts = data['neighbourhood_group'].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
neighbourhood_counts.plot.pie(autopct='%1.1f%%', startangle=140, cmap='tab20', labels=neighbourhood_counts.index)
plt.title('Distribution of Listings by Neighbourhood Group')
plt.ylabel('')  # Hide the y-label for a cleaner look
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose pie chart to show the distribution of neighbourhood group. It is the best way to portray that which group occupies larger area and which occupies smaller area.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Most no. of airbnbs are located in Manhattan even though they are the most expensive accounting to 44.3%
# 2. Followed by Brooklyn with 41.1% share.
# 3. The least no. of airbnbs are in Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights help us to identify that which area has the largest share and which one has the lowest. This will help us to market our airbnbs in those specific areas and if need arises, we can open more no. of airbnbs in areas which has less market share.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# x-axis = neighbourhood_group | y-axis = reviews_per_month
# Bar chart

plt.figure(figsize=(10,3))
sns.barplot(x=data['neighbourhood_group'],y=data['reviews_per_month'])
plt.title('Neighbourhood Area v/s reviews_per_month')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the relationship between neighbourhood and reviews per month, in which one is categorical data and another is numerical data, I chose bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Queens is the most popular neighbourhood in terms of reviews of month.
# 2. Followed by Staten Island.
# 3. Manhattan has the least reviews per month even though price in that area is the highest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This chart shows us that which neighbourhood is the most in terms of reviews. Neighbourhood which has less review can work more to get more reviews.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# x-axis = room_type | y-axis = price
# Bar chart

plt.figure(figsize=(6,4))
sns.barplot(x = data['room_type'], y= data['price'], color = 'orange' )
plt.title("Room type Price Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the relationship between room type and price, in which one is categorical data and another is numerical data, I chose  bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Entire apartment is the most expensive followed by private room.
# 2. The least expensive is shared room

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps to analyze price distribution as per room type.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# x-axis = neighbourhood
# Count plot

plt.figure(figsize=(10,6))
sns.countplot(x=data['neighbourhood_group'])
plt.xticks(rotation=45)
plt.title("Count of airbnbs in specific Neighbourhood")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To count the no. of airbnbs in all the neighbourhood, I chose count plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Most no. of airbnbs are in Manhattan followed by Brooklyn.
# 2. Least no. of airbnbs are in Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps us to quantify no. of airbnbs in all the neighbourhood groups.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# x-axis = price  | y-axis = calculated_host_listings_count
# Scatter Plot

plt.figure(figsize=(6,4))
sns.scatterplot(x= data['price'], y = data['calculated_host_listings_count'])
plt.title("Relationship b/w price & total listings")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the relationship b/w price and total listing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no relation b/w both the parameters. It's kind of stagnant.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The above chart tells us that total listings does not depend on price of airbnb. So, organization's focus should not focus on price, rather on other parameters, for instance, marketing.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# x-axis = room_type | y-axis = availability_365
# Bar chart

plt.figure(figsize=(5,5))
sns.barplot(x = data['room_type'], y = data['availability_365'], color = 'red')
plt.title("Availibility as per room type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the relationship between room type and average availibility, in which one is categorical data and another is numerical data, I chose  bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Shared room is the most available in a year.
# 2. Least available room is the private one.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps us know the availability of different room types.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# x-axis = neighbourhood_group | y-axis = price
# Box Plot

plt.figure(figsize= (6,4))
sns.boxplot(x = data['neighbourhood_group'], y = data['price'])
plt.title("Relationship b/w neighbourhood_group & price ")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify outliers between neighbourhood and price, I chose to boxplot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. There are certain outliers in all the neighbourhood.
# 2. All the outliers are on the higher range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps us to know the outliers, prices that vary from others on the larger extent.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# x-axis = neighbourhood_group | y-axis = availibility_365
# Bar chart

plt.figure(figsize = (10,4))
sns.barplot(x = data['neighbourhood_group'], y = data['availability_365'], color = 'cyan')
plt.title("Average availibility as per Neighbourhood")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the relationship between neighbourhood and average availibility, in which one is categorical data and another is numerical data, I chose  bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The average availibility is the highest in Staten Island.
# 2. The least is in Brooklyn

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps us to know the average availibility as per neighbourhood.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# room_type
# Pie chart

room_type_counts = data['room_type'].value_counts()

plt.figure(figsize=(6, 6))
room_type_counts.plot.pie(autopct='%1.1f%%', startangle=140, labels= room_type_counts.index)
plt.title('Distribution of Listings by Room Type')
plt.ylabel('')  # Hide the y-label for a cleaner look
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the distribution of room type

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Entire apartment has the largest market share - 52%.
# 2. Shared room has the smallest market share - 2.4%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps to visualize the distribution of room types.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# x-axis = neighbourhood_group | y-axis = minimun_nights
# Bar plot

plt.figure(figsize=(10,5))
sns.barplot(x = data['neighbourhood_group'], y = data['minimum_nights'])
plt.title("Relationship b/w neighbourhood_group  & minimun_nights")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the relationship between neighbourhood and minimum nights, in which one is categorical data and another is numerical data, I chose  bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Manhattan area has the most minimum nights.
# 2. Staten Island has the least minimum nights.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It shows the specification of minimum nights in each neighbourhood area.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Price Distribution
# Histogram

plt.figure(figsize=(10, 6))
plt.hist(data['price'], bins=50, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Price Distribution', fontsize=16)
plt.xlabel('Price', fontsize=14)
plt.ylabel('Number of Listings', fontsize=14)
plt.yscale('log')  # Use logarithmic scale to better visualize skewed data
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the price distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The chart is right skewed. This means as the price increases, the no. of listings reduce.
# 2. Most of the airbnbs are priced at lower price.
# 3. High priced listings are rare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It gives complete overview of price distribution as well as outliers, helping to analyze the prices.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# x-axis = room_type | y-axis = price
# Bar chart

plt.figure(figsize= (8,4))
sns.barplot(x = data['room_type'], y = data['price'])
plt.title("Room type Vs Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Entire apartment is the most expensive
# 2. Shared room is the least expensive.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numerical_columns = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
corr_data = data[numerical_columns].corr()

# %%
sns.heatmap(corr_data, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the correlation between all the numerical parameters.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. There is negative correlation b/w price & no. of reviews as less people could afford the place.
# 2. A positive correlation could exist b/w Reviews Per Month vs. Availabilit, suggesting that highly available listings get reviewed more often.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(data)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot helps to visualize all the parameters together at one place.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Price vs. Minimum Nights: Listings with extremely high prices often have longer minimum night requirements, which could indicate luxury or event-specific accommodations.
# 2. Price vs. Availability: Listings with higher availability (availability_365) tend to have a wide range of prices, but affordable options dominate.
# 3. Price vs. Reviews Per Month: Expensive listings may have fewer reviews, possibly due to limited affordability or demand.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
#
# 1. Affordable Listings: Maintain competitive pricing strategies, focusing on properties priced under $200. Emphasize amenities and reviews to boost bookings.
# 2. Mid-Range Listings ($200 - $500): Enhance property attractiveness with unique features or special offers (e.g., discounts for longer stays).
# 3. High-End Listings (> $500): Target niche markets (e.g., business travelers, tourists on extended stays). Highlight unique property features and premium services to justify the higher price point.
# 4. Different Room Types: Introduce more variety in room types (e.g., shared rooms or entire homes) to cater to different budgets and group sizes.
# 5. Focus marketing efforts on popular neighbourhoods within NYC, where demand is highest.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# To achieve their business objectives, the client should leverage data-driven insights to optimize pricing, enhance listing visibility, and improve the guest experience, ensuring a competitive edge in the dynamic Airbnb market. Continuous monitoring and adaptation to market trends will help maintain and grow their business success.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
